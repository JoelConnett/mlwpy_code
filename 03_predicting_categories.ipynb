# %%
from mlwpy import *
# %matplotlib inline

# %%
iris = datasets.load_iris()

iris_df = pd.DataFrame(iris.data,
                       columns=iris.feature_names)
iris_df['target'] = iris.target
display(pd.concat([iris_df.head(3),
                   iris_df.tail(3)]))
sns.pairplot(iris_df, hue='target', size=1.5);
# Out:
#        sepal length (cm)     sepal width (cm)    petal length (cm)  \
# 0                 5.1000               3.5000               1.4000
# 1                 4.9000               3.0000               1.4000
# 2                 4.7000               3.2000               1.3000
# 147               6.5000               3.0000               5.2000
# 148               6.2000               3.4000               5.4000
# 149               5.9000               3.0000               5.1000
#
#         petal width (cm)  target
# 0                 0.2000       0
# 1                 0.2000       0
# 2                 0.2000       0
# 147               2.0000       2
# 148               2.3000       2
# 149               1.8000       2

# %% [markdown]
# ### 3.5.1 Defining Similarity
#
# 20 distance metrics are defined in sklearn's `neighbors.DistanceMetric`
#
# ### 3.5.4 k-NN, Parameters, and Nonparametric Methods
#
# k-NN requires **all** of the input data. These types of learning algorithms are classified as
# **nonparametric**. Nonparametric algorithms means that the relationship between features and targets
# can't be captured with parameters alone (they need samples).
#
# Parametric models make assumptions about the data's features and choose a model that best describes
# their relationship with the targets.
#
# ### 3.5.5 Building a k-NN Classification Model

# %%
# simple train-test split
(iris_train_ftrs, iris_test_ftrs,
 iris_train_tgt,  iris_test_tgt) = skms.train_test_split(iris.data,
                                                         iris.target,
                                                         test_size=.25)
print("Train features shape:", iris_train_ftrs.shape)
print("Test features shape:",  iris_test_ftrs.shape)

# default n_neighbors = 5
knn   = neighbors.KNeighborsClassifier(n_neighbors=3)
fit   = knn.fit(iris_train_ftrs, iris_train_tgt)
preds = fit.predict(iris_test_ftrs)
print(preds)

# evaluate our predictions against the held-back testing targets
print("3NN accuracy:",
      metrics.accuracy_score(iris_test_tgt, preds))
# Out:
# Train features shape: (112, 4)
# Test features shape: (38, 4)
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0]
# 3NN accuracy: 1.0

# %% [markdown]
# $$c2=a2+b2or  c=a2+b2‾‾‾‾‾‾‾√$$
